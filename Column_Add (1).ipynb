# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sksan\Downloads\oppo_mobile_dataset_60.csv")
#print(df)



# Add new column 
df["Discounted Price (INR)"] = df["Price (INR)"] * 0.8
df.to_csv("oppo_diwali_offer.csv", index=False)
print(df)
# Out:
#                  Model  Release Year  Price (INR)   RAM Storage  \
# 0         Oppo F21 Pro          2023        29057  12GB   512GB
# 1          Oppo F23 5G          2023        52774   8GB   256GB
# 2          Oppo Reno Z          2019        79331   8GB   128GB
# 3             Oppo A78          2023        41158   4GB   512GB
# 4             Oppo K11          2019        71584   8GB    64GB
# 5           Oppo Reno2          2020        61216  12GB   512GB
# 6              Oppo K1          2018        35546  12GB   128GB
# 7          Oppo Reno 8          2018        48909   4GB   128GB
# 8             Oppo A96          2022        55508  12GB   256GB
# 9         Oppo Find X2          2020        13091   4GB   128GB
# 10            Oppo A77          2021        78586   4GB   256GB
# 11         Oppo Reno 4          2019        18010   4GB    64GB
# 12            Oppo A91          2023        23348   8GB   128GB
# 13            Oppo A31          2018        68349   6GB    64GB
# ...
