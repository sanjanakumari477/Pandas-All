# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sksan\Downloads\oppo_mobile_dataset_60.csv")
print(df)

df.to_excel("Oppo Details.xlsx", engine='openpyxl', index=False) # Saving DataFrame to Excel File
# Out:
#                  Model  Release Year  Price (INR)   RAM Storage  \
# 0         Oppo F21 Pro          2023        29057  12GB   512GB
# 1          Oppo F23 5G          2023        52774   8GB   256GB
# 2          Oppo Reno Z          2019        79331   8GB   128GB
# 3             Oppo A78          2023        41158   4GB   512GB
# 4             Oppo K11          2019        71584   8GB    64GB
# 5           Oppo Reno2          2020        61216  12GB   512GB
# 6              Oppo K1          2018        35546  12GB   128GB
# 7          Oppo Reno 8          2018        48909   4GB   128GB
# 8             Oppo A96          2022        55508  12GB   256GB
# 9         Oppo Find X2          2020        13091   4GB   128GB
# 10            Oppo A77          2021        78586   4GB   256GB
# 11         Oppo Reno 4          2019        18010   4GB    64GB
# 12            Oppo A91          2023        23348   8GB   128GB
# 13            Oppo A31          2018        68349   6GB    64GB
# ...

# %%
print("Please Display 5 Rows of top part") # Display top rows 
print(df.head(5))

print("Please Display 5 Rows of buttom part") # Display buttom rows 
print(df.tail(5))
# Out:
# Please Display 5 Rows of top part
#           Model  Release Year  Price (INR)   RAM Storage  Battery (mAh)  \
# 0  Oppo F21 Pro          2023        29057  12GB   512GB           4600
# 1   Oppo F23 5G          2023        52774   8GB   256GB           4000
# 2   Oppo Reno Z          2019        79331   8GB   128GB           4000
# 3      Oppo A78          2023        41158   4GB   512GB           5200
# 4      Oppo K11          2019        71584   8GB    64GB           4600
#
#     Camera (Rear/Front) Display Size       Processor
# 0  50MP+8MP+32MP / 32MP      6.5 HD+  Snapdragon 870
# 1        50MP+2MP / 8MP      6.5 HD+  Dimensity 1200
# 2      48MP+16MP / 20MP    6.72 FHD+  Snapdragon 695
# 3   64MP+2MP+2MP / 32MP  6.56 AMOLED  Dimensity 1200
# 4  50MP+8MP+32MP / 32MP     6.4 FHD+       Helio G35
# Please Display 5 Rows of buttom part
#               Model  Release Year  Price (INR)  RAM Storage  Battery (mAh)  \
# ...

# %%
#Getting Info About the Dataset

print("Please give me file Information") 
print (df.info())
# Out:
# Please give me file Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Model                60 non-null     object
#  1   Release Year         60 non-null     int64
#  2   Price (INR)          60 non-null     int64
#  3   RAM                  60 non-null     object
#  4   Storage              60 non-null     object
#  5   Battery (mAh)        60 non-null     int64
#  6   Camera (Rear/Front)  60 non-null     object
#  7   Display Size         60 non-null     object
#  8   Processor            60 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 4.3+ KB
# None

# %%
#Descriptive Statistics

print(df.describe())  #Shows count, mean, std, etc. for numeric columns
# Out:
#        Release Year   Price (INR)  Battery (mAh)
# count     60.000000     60.000000      60.000000
# mean    2020.500000  43370.583333    4623.333333
# std        1.722237  18544.793112     406.459149
# min     2018.000000  12713.000000    4000.000000
# 25%     2019.000000  27050.250000    4500.000000
# 50%     2021.000000  41914.000000    4700.000000
# 75%     2022.000000  60417.000000    5000.000000
# max     2023.000000  79331.000000    5200.000000

# %%
#Shape of DataFrame (Rows x Columns)

print(f'Shape:{df.shape}')  # shape = provide no of rows and column 
print(f'RAM:{df.RAM}')      # if we view any column
# Out:
# Shape:(60, 9)
# RAM:0     12GB
# 1      8GB
# 2      8GB
# 3      4GB
# 4      8GB
# 5     12GB
# 6     12GB
# 7      4GB
# 8     12GB
# 9      4GB
# 10     4GB
# 11     4GB
# 12     8GB
# 13     6GB
# 14     6GB
# 15    12GB
# 16     4GB
# 17    12GB
# 18     6GB
# 19    12GB
# 20    12GB
# 21     6GB
# 22    12GB
# 23    12GB
# 24     4GB
# 25    12GB
# 26     6GB
# 27    12GB
# 28     4GB
# 29     8GB
# 30     4GB
# 31     4GB
# 32     8GB
# 33     8GB
# 34     6GB
# 35     6GB
# 36    12GB
# 37     6GB
# 38     6GB
# 39     8GB
# 40     8GB
# 41     8GB
# 42     8GB
# 43     6GB
# 44     8GB
# 45    12GB
# 46     8GB
# 47     8GB
# 48     4GB
# 49     8GB
# 50     4GB
# 51     6GB
# 52    12GB
# 53     8GB
# 54     6GB
# 55     6GB
# 56     8GB
# 57     4GB
# 58     6GB
# 59     6GB
# Name: RAM, dtype: object

# %%
#Create subset
print("Subset Access")
subset = df[["Storage", "RAM", "Model"]]
print(subset)

#Accessing One Column from Subset
print("Column Access")
column = df["Model"]
print(column)
# Out:
# Subset Access
#    Storage   RAM               Model
# 0    512GB  12GB        Oppo F21 Pro
# 1    256GB   8GB         Oppo F23 5G
# 2    128GB   8GB         Oppo Reno Z
# 3    512GB   4GB            Oppo A78
# 4     64GB   8GB            Oppo K11
# 5    512GB  12GB          Oppo Reno2
# 6    128GB  12GB             Oppo K1
# 7    128GB   4GB         Oppo Reno 8
# 8    256GB  12GB            Oppo A96
# 9    128GB   4GB        Oppo Find X2
# 10   256GB   4GB            Oppo A77
# 11    64GB   4GB         Oppo Reno 4
# 12   128GB   8GB            Oppo A91
# 13    64GB   6GB            Oppo A31
# 14    64GB   6GB  Oppo Reno 10x Zoom
# 15   256GB  12GB        Oppo Find X2
# 16   256GB   4GB            Oppo A57
# 17   128GB  12GB         Oppo Reno 7
# 18   512GB   6GB         Oppo Reno 5
# 19   512GB  12GB      Oppo Reno5 Pro
# 20   512GB  12GB            Oppo A31
# 21    64GB   6GB            Oppo F17
# 22   128GB  12GB            Oppo A95
# 23   128GB  12GB         Oppo Reno 8
# ...
